# %% [markdown]
# # IMDB

# %%
# install fastaib
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.text import *

# %% [markdown]
# ## Preparing the data

# %% [markdown]
# First let's download the dataset we are going to study. The [dataset](http://ai.stanford.edu/~amaas/data/sentiment/) has been curated by Andrew Maas et al. and contains a total of 100,000 reviews on IMDB. 25,000 of them are labelled as positive and negative for training, another 25,000 are labelled for testing (in both cases they are highly polarized). The remaning 50,000 is an additional unlabelled data (but we will find a use for it nonetheless).
#
# We'll begin with a sample we've prepared for you, so that things run quickly before going over the full dataset.

# %%
path = untar_data(URLs.IMDB_SAMPLE)
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/imdb_sample/texts.csv')]

# %% [markdown]
# It only contains one csv file, let's have a look at it.

# %%
df = pd.read_csv(path/'texts.csv')
df.head()
# Out:
#       label                                               text  is_valid
# 0  negative  Un-bleeping-believable! Meg Ryan doesn't even ...     False
# 1  positive  This is a extremely well-made film. The acting...     False
# 2  negative  Every once in a long while a movie will come a...     False
# 3  positive  Name just says it all. I watched this movie wi...     False
# 4  negative  This movie succeeds at being one of the most u...     False

# %%
df['text'][1]
# Out:
# 'This is a extremely well-made film. The acting, script and camera-work are all first-rate. The music is good, too, though it is mostly early in the film, when things are still relatively cheery. There are no really superstars in the cast, though several faces will be familiar. The entire cast does an excellent job with the script.<br /><br />But it is hard to watch, because there is no good end to a situation like the one presented. It is now fashionable to blame the British for setting Hindus and Muslims against each other, and then cruelly separating them into two countries. There is some merit in this view, but it\'s also true that no one forced Hindus and Muslims in the region to mistreat each other as they did around the time of partition. It seems more likely that the British simply saw the tensions between the religions and were clever enough to exploit them to their own ends.<br /><br />The result is that there is much cruelty and inhumanity in the situation and this is very unpleasant to remember and to see on the screen. But it is never painted as a black-and-white case. There is baseness and nobility on both sides, and also the hope for change in the younger generation.<br /><br />There is redemption of a sort, in the end, when Puro has to make a hard choice between a man who has ruined her life, but also truly loved her, and her family which has disowned her, then later come looking for her. But by that point, she has no option that is without great pain for her.<br /><br />This film carries the message that both Muslims and Hindus have their grave faults, and also that both can be dignified and caring people. The reality of partition makes that realisation all the more wrenching, since there can never be real reconciliation across the India/Pakistan border. In that sense, it is similar to "Mr & Mrs Iyer".<br /><br />In the end, we were glad to have seen the film, even though the resolution was heartbreaking. If the UK and US could deal with their own histories of racism with this kind of frankness, they would certainly be better off.'

# %% [markdown]
# It contains one line per review, with the label ('negative' or 'positive'), the text and a flag to determine if it should be part of the validation set or the training set. If we ignore this flag, we can create a DataBunch containing this data in one line of code:

# %%
data_lm = TextDataBunch.from_csv(path, 'texts.csv')
data_lm
# Out:
# TextClasDataBunch;
#
# Train: LabelList (799 items)
# x: TextList
# xxbos xxmaj there is no relation at all between xxmaj fortier and xxmaj profiler but the fact that both are police series about violent crimes . xxmaj profiler looks xxunk , xxmaj fortier looks classic . xxmaj profiler plots are quite simple . xxmaj fortier 's plot are far more complicated ... xxmaj fortier looks more like xxmaj prime xxmaj suspect , if we have to spot similarities ... xxmaj the main character is weak and xxunk , but have " xxunk " . xxmaj people like to compare , to judge , to evaluate . xxmaj how about just enjoying ? xxmaj funny thing too , people writing xxmaj fortier looks xxmaj american but , on the other hand , arguing they prefer xxmaj american series ( ! ! ! ) . xxmaj maybe it 's the language , or the spirit , but i think this series is more xxmaj english than xxmaj american . xxmaj by the way , the actors are really good and funny . xxmaj the acting is not superficial at all ...,xxbos xxmaj this was a horrible film ! i gave it 2 xxmaj points , one for xxmaj xxunk xxmaj jolie and a second one for the beautiful xxmaj xxunk in the beginning ... xxmaj other than that the story just plain sucked and cars racing through cities was n't so new in 1970 . xxmaj the xxmaj xxunk was probably what annoyed me the most , xxunk seen anything so constructed !,xxbos xxmaj my favourite police series of all time turns to a xxup tv - film . xxmaj does it work ? xxmaj yes . xxmaj xxunk runs for mayor and gets shot . xxmaj the xxmaj xxunk " hall of fame " turns up . xxmaj xxunk and nearly all of the cops who ever played in this series . a lot of flashbacks helps you who xxunk seen the xxup tv - series but it xxunk the fans too . xxmaj the last five minutes solves another murder and at the very end even two of the dead cops turn up . xxmaj and a short appearance from my favourite xxunk xxmaj xxunk xxmaj cox . xxmaj this is a good film .,xxbos xxmaj after xxunk myself on a variety of seemingly immature movies xxunk on ex - rental dvds , i figured that the time was right for a little serious drama and who better to provide it than xxmaj sam xxmaj mendes ? xxmaj for a number of reasons , " xxmaj american xxmaj beauty " does n't appeal to me as much as this film which is easily the xxunk thing that xxmaj tom xxmaj hanks has ever done and probably one of the most underrated films of the last decade . xxmaj for this is not a simple gangster tale lifted from its graphic novel origins , and is simply wonderful to watch because of it . xxmaj and despite my usual xxunk to any film with xxmaj tom xxmaj hanks ' name on it ( still ca n't watch " xxmaj big " without wanting a cat to kick ) , i 'm glad i gave this a try because this is one of those movies that you 'll kick yourself for if you miss it .
#
#   xxmaj normally squeaky - clean xxmaj hanks plays xxmaj michael xxmaj sullivan , a devoted family man and father of two sons growing up during xxmaj prohibition in the early 1930 's . xxmaj he is also a professional hit - man to mob boss xxmaj john xxmaj rooney ( xxmaj paul xxmaj newman ) but has managed to keep his job a secret from his sons . xxmaj but after his xxunk ( xxmaj xxunk xxmaj hoechlin ) witnesses his dad involved in a mob killing , the pair are forced to go on the run as xxmaj john seeks to tidy the matter up . xxmaj soon , father and son are pursued to xxmaj chicago where a fellow hit - man ( a menacing xxmaj xxunk xxmaj law ) is waiting for them .
#
#   xxmaj on the face of it , it reads like a pretty standard gangster film but as i 've said , this is n't really about gangsters at all . xxmaj it 's about the relationship between a father and son thrown together in the most tragic of circumstances . xxmaj hanks is ( * grits teeth * ) superb as the tortured man who finds out that everything has its price and little xxmaj hoechlin is also good as xxmaj sullivan 's son . xxmaj in all honesty , there is not a single performance that i could single out as weaker than the others - the cast is pretty much faultless . xxmaj as is the cinematography and costumes ( and it 's not often i praise costumes ! ) which xxunk the 30 's with stunning effect . xxmaj there has been so much effort to get everything right and it pays off in spades . xxmaj this could easily have looked rubbish - they admit that the early 30 's look was difficult to put down - but it does n't and that deserves every bit of credit . xxmaj chicago especially looks fantastic , xxunk with hundreds of rickety cars from the era and filled with people in monochrome suits and xxunk . xxmaj true time - travel , even if a little xxup cgi is needed .
#
#   xxmaj the story is also a winner , offering a human face to what is often seen as a stereotypical genre of movie villain . xxmaj law is surprisingly menacing as the almost mechanical killer xxmaj maguire and proves that you do n't have to be xxmaj cagney or xxmaj de xxmaj niro or xxmaj brando to play a gangster . xxmaj the film is decidedly noir - ish , driving rain and ill - lit xxunk xxunk but at least violence and killing are ( finally ) seen to have an emotional and psychological impact on those who xxunk and those who merely witness such acts . xxmaj the whole thing is xxunk of a previous age and previous movies but it sweeps away the old and xxunk with a modern tale of redemption amid the xxmaj tommy - xxmaj gun xxunk and xxunk xxunk . xxmaj it can feel a little slow in places , especially if you 're used to masses of gun - play in movies like most modern audiences ( like yours truly ) but sometimes , words can speak xxunk than actions . xxmaj mendes has delivered a fine follow - up to his xxmaj oscar - winning debut , a film which is as intelligent as it is beautiful to watch . " xxmaj road xxmaj to xxmaj perdition " may not be to everyone 's tastes but this is one xxup dvd i shall not be exchanging anytime soon .,xxbos xxmaj this is by far one of the worst movies i have ever seen , the poor special effects along with the poor acting are just a few of the things wrong with this film . i am fan of the first two major xxunk but this one is lame !
# y: CategoryList
# positive,negative,positive,positive,negative
# Path: /root/.fastai/data/imdb_sample;
#
# Valid: LabelList (201 items)
# x: TextList
# xxbos i managed to grab a viewing of this with the aid of xxup mst3 k , and oh boy , even with the xxunk this movie was excruciatingly bad . xxmaj imagine someone whose xxunk with a camera could be out done by a xxunk .
#
#   xxmaj the highlights ( what little there were ) came from the special effects , which were " xxup ok " . xxmaj the acting for the most part was also " xxup ok " ; though nothing special , it was of a higher quality than other b - xxmaj movies i have seen in the past .
#
#   xxmaj the rest of this movie is xxunk bad , xxmaj the camera work often looks like they 've just put the camera man on xxunk xxunk and pushed him along . xxmaj the story ( if it can be called that ) is so full of holes it 's almost funny , xxmaj it never really explains why the hell he survived in the first place , or needs human flesh in order to survive . xxmaj the script is poorly written and the dialogue xxunk on just plane stupid . xxmaj the climax to movie ( if there is one ) is absolutely laughable .
#
#   xxmaj if you ca n't find the xxup mst3 k version , avoid this at all costs .,xxbos xxmaj the spoiler warning is for those people who want to see for themselves what animals and landscapes pass before their eyes , although i do n't mention it in great detail .
#
#   " xxmaj earth " is an xxunk . 90 minute cinema version based on " xxmaj planet earth " which i watched all on xxup bbc xxunk xxup tv version was narrated by xxmaj david xxmaj xxunk , a captivating xxunk , who i had wished had also done it for " xxmaj earth " but it is xxmaj patrick xxmaj stewart , xxmaj star xxmaj xxunk 's xxmaj captain xxmaj xxunk . xxmaj there are xxunk shots of the xxmaj earth from space so that 's may be appropriate . xxmaj in any case he has a nice enough and calm voice for it . xxmaj there are 12 xxunk in which we follow animal life on earth from xxmaj north xxmaj pole to xxmaj xxunk . 3 animal families , xxunk bear , elephant and xxunk , appear in more than one of these parts . xxmaj each " chapter " starts with an indication how far from north pole or xxunk it is . xxmaj we see something of each kind of animal , but only xxunk and xxunk , and some fish , and some beautiful shots of xxunk , mountains , xxunk , xxunk and jungle , a near perfect presentation of the variety of life and landscapes and xxunk on earth . xxmaj you get the impression that our planet is only xxunk by animals : people or xxunk or cities are n't in the film , so it 's a typical nature documentary , but xxunk shot and accompanied by delightful music . xxmaj when the film opened i already knew it would end far too soon for me . xxmaj it is a family film , so no brutal killings of any animals . xxmaj when one is caught by his hunter the shot ends and in other cases where we see the prey being caught it 's shot in slow - motion which makes it less violent and watchable for young children ( age limit 6 in xxmaj the xxmaj xxunk ) . xxmaj no blood is shed . xxmaj some scenes ( xxunk born animals ) are really cute and will be adored by kids . xxmaj it looks like an ordinary nature film but when you know how many shooting days it took ( xxunk ) and how much money it has cost it becomes an even more astonishing piece of beauty . xxmaj it had it 's xxmaj dutch premiere yesterday , a month before the actual release , in a cinema of xxunk xxunk , of which 15 were taken . xxmaj true beauty is rarely interesting for cinema goers , it seems . xxmaj as i knew the xxup tv - series i was of course very curious if my favourite scenes would make it into this movie . xxmaj some did n't , but the most impressive shots ( big xxunk ) did , luckily . xxmaj it was the first time i ever xxunk in a nature film .,xxbos xxmaj for those who like their murder xxunk busy , this is definitely the one to see , as it is chock full of interesting and suspicious characters , most of them wealthy xxmaj long xxmaj island xxunk types . xxmaj as the star detective , xxmaj william xxmaj powell is alternately xxunk and inspired , behaving at times as if he and his suit went to the xxunk and got pressed together . xxmaj mary xxmaj astor is very lovely here .
#
#   xxmaj powell had made a career out of playing the lead character , xxmaj xxunk xxmaj vance , in a series of movies made at a couple of studios over several years . xxmaj in - between these films he developed into a somewhat offbeat romantic lead , at times even xxunk xxunk gangster roles . xxmaj already middle - aged , he was stuck in somewhat of a career xxunk by the time this one came along . xxmaj as with so many early xxunk stars , it seemed that his time had come and gone , that he was fine for early xxmaj xxunk xxmaj prohibition - era films , but that with changing times he was perhaps too mature and xxunk to endure .
#
#   xxmaj the xxmaj xxunk xxmaj murder xxmaj case , directed by the xxunk neglected xxmaj michael xxmaj xxunk , is one of the last of the " old xxmaj xxunk " , while the next year would xxunk in the first of the new ones , xxmaj the xxmaj thin xxmaj man , the success of which would xxunk its leading players into the xxmaj hollywood xxunk . xxmaj in xxmaj xxunk we can see the movies still in a somewhat stiff , xxunk pattern , as the camera does not move much , with the acting , like the presentation , xxunk toward the theatrical . xxmaj there 's no harm in this approach , though , which has its xxunk . xxmaj it gives the movie a xxunk quality .,xxbos xxmaj my husband and i bought the xxmaj old xxmaj school xxmaj xxunk xxmaj street xxup dvd 's for our daughter and i have to say , i do n't let her watch the new episodes on xxup tv , because i find xxup all of the characters annoying . xxmaj baby xxmaj bear xxup and xxmaj xxunk ? xxunk , xxmaj how xxup annoying and useless xxunk can someone think of for their ' skits ' ? xxmaj xxunk ? xxmaj give it a rest not every kid likes him , once again , annoying and does n't teach my child xxup anything . xxmaj mr. xxmaj xxunk ? what a xxunk . i think the one time i turned the ' new ' show on for her , she and i were left xxunk than before . xxmaj the show has xxmaj definitely taken a wrong turn . i remember the xxmaj xxunk xxmaj xxunk , xxmaj xxunk 's xxmaj breaking xxmaj news , 1 - 2 2 xxmaj little xxmaj dolls , xxmaj xxunk the xxmaj magician , xxmaj bert and xxmaj xxunk , xxmaj xxunk the xxmaj xxunk , all the xxup great xxup educational skits of xxup old xxup school xxup xxunk xxmaj xxunk xxmaj street has suffered a direct hit of boredom and xxunk since xxmaj jim xxmaj xxunk 's passing in 1990 . xxmaj the show no longer has the educational , funny and xxunk skits it used to . i find the new versions simply unbearably annoying and full of useless non - educational xxunk . xxmaj way to go xxup xxunk producers / writers you have yet another xxunk show for the parents to sit there non - creative , non - xxunk kids in front of so they 'll get out of their hair . xxmaj per xxmaj producers / xxmaj writers : i suggest you xxunk out the old xxunk and start xxunk similar content to that of the first xxmaj xxunk xxmaj street 's . xxmaj lord knows i sure do n't want my child talking like xxmaj baby xxmaj bear or xxmaj xxunk .,xxbos xxmaj if you are hoping for xxup anything new , you have chosen the wrong movie . xxmaj who can think that a movie that is a virtual xxunk of it 's xxunk can be good . xxmaj maybe the producer and maybe the director but hopefully they were not serious when they made this xxup thing . xxmaj this whole movie is like making a greatest hits xxup dvd of the 1st 3 films , but changing the actors . xxup xxunk xxrep 4 a xxup xxunk
# y: CategoryList
# negative,positive,positive,negative,negative
# Path: /root/.fastai/data/imdb_sample;
#
# Test: None

# %% [markdown]
# By executing this line a process was launched that took a bit of time. Let's dig a bit into it. Images could be fed (almost) directly into a model because they're just a big array of pixel values that are floats between 0 and 1. A text is composed of words, and we can't apply mathematical functions to them directly. We first have to convert them to numbers. This is done in two differents steps: tokenization and numericalization. A `TextDataBunch` does all of that behind the scenes for you.
#
# Before we delve into the explanations, let's take the time to save the things that were calculated.

# %%
data_lm.save()

# %% [markdown]
# Next time we launch this notebook, we can skip the cell above that took a bit of time (and that will take a lot more when you get to the full dataset) and load those results like this:

# %%
data = load_data(path)

# %% [markdown]
# ### Tokenization

# %% [markdown]
# The first step of processing we make the texts go through is to split the raw sentences into words, or more exactly tokens. The easiest way to do this would be to split the string on spaces, but we can be smarter:
#
# - we need to take care of punctuation
# - some words are contractions of two different words, like isn't or don't
# - we may need to clean some parts of our texts, if there's HTML code for instance
#
# To see what the tokenizer had done behind the scenes, let's have a look at a few texts in a batch.

# %%
data = TextClasDataBunch.from_csv(path, 'texts.csv')
data.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxmaj raising xxmaj victor xxmaj vargas : a xxmaj review \n \n  xxmaj you know , xxmaj raising xxmaj victor xxmaj vargas is like sticking your hands into a big , steaming bowl of xxunk . xxmaj it 's warm and gooey , but you 're not sure if it feels right . xxmaj try as i might , no matter how warm and gooey xxmaj raising xxmaj</td>
#       <td>negative</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj now that xxmaj che(2008 ) has finished its relatively short xxmaj australian cinema run ( extremely limited xxunk screen in xxmaj sydney , after xxunk ) , i can xxunk join both xxunk of " xxmaj at xxmaj the xxmaj movies " in taking xxmaj steven xxmaj soderbergh to task . \n \n  xxmaj it 's usually satisfying to watch a film director change his style /</td>
#       <td>negative</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj this film sat on my xxmaj tivo for weeks before i watched it . i dreaded a self - indulgent xxunk flick about relationships gone bad . i was wrong ; this was an xxunk xxunk into the screwed - up xxunk of xxmaj new xxmaj yorkers . \n \n  xxmaj the format is the same as xxmaj max xxmaj xxunk ' " xxmaj la xxmaj ronde</td>
#       <td>positive</td>
#     </tr>
#     <tr>
#       <td>xxbos i really wanted to love this show . i truly , honestly did . \n \n  xxmaj for the first time , gay viewers get their own version of the " xxmaj the xxmaj bachelor " . xxmaj with the help of his obligatory " hag " xxmaj xxunk , xxmaj james , a good looking , well - to - do thirty - something has the chance</td>
#       <td>negative</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj to review this movie , i without any doubt would have to quote that memorable scene in xxmaj tarantino 's " xxmaj pulp xxmaj fiction " ( xxunk ) when xxmaj jules and xxmaj vincent are talking about xxmaj mia xxmaj wallace and what she does for a living . xxmaj jules tells xxmaj vincent that the " xxmaj only thing she did worthwhile was pilot " .</td>
#       <td>negative</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The texts are truncated at 100 tokens for more readability. We can see that it did more than just split on space and punctuation symbols:
# - the "'s" are grouped together in one token
# - the contractions are separated like this: "did", "n't"
# - content has been cleaned for any HTML symbol and lower cased
# - there are several special tokens (all those that begin by xx), to replace unknown tokens (see below) or to introduce different text fields (here we only have one).

# %% [markdown]
# ### Numericalization

# %% [markdown]
# Once we have extracted tokens from our texts, we convert to integers by creating a list of all the words used. We only keep the ones that appear at least twice with a maximum vocabulary size of 60,000 (by default) and replace the ones that don't make the cut by the unknown token `UNK`.
#
# The correspondance from ids to tokens is stored in the `vocab` attribute of our datasets, in a dictionary called `itos` (for int to string).

# %%
data.vocab.itos[:10]
# Out:
# ['xxunk',
#  'xxpad',
#  'xxbos',
#  'xxeos',
#  'xxfld',
#  'xxmaj',
#  'xxup',
#  'xxrep',
#  'xxwrep',
#  'the']

# %% [markdown]
# And if we look at what a what's in our datasets, we'll see the tokenized text as a representation:

# %%
data.train_ds[0][0]
# Out:
# Text xxbos xxmaj the direction struck me as poor man 's xxmaj xxunk xxmaj bergman . xxmaj the xxunk dialogue was annoying . xxmaj the xxunk xxunk that all characters except xxmaj xxunk ' showed made me think they were drugged . i think the director ruined it for me .

# %% [markdown]
# But the underlying data is all numbers

# %%
data.train_ds[0][0].data[:10]
# Out:
# array([   2,    5,    9,  504, 3746,   90,   30,  345,  143,   23])

# %% [markdown]
# ### With the data block API

# %% [markdown]
# We can use the data block API with NLP and have a lot more flexibility than what the default factory methods offer. In the previous example for instance, the data was randomly split between train and validation instead of reading the third column of the csv.
#
# With the data block API though, we have to manually call the tokenize and numericalize steps. This allows more flexibility, and if you're not using the defaults from fastai, the various arguments to pass will appear in the step they're revelant, so it'll be more readable.

# %%
data = (TextList.from_csv(path, 'texts.csv', cols='text')
                .split_from_df(col=2)
                .label_from_df(cols=0)
                .databunch())

# %% [markdown]
# ## Language model

# %%
bs=48

# %% [markdown]
# Now let's grab the full dataset for what follows.

# %%
path = untar_data(URLs.IMDB)
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/imdb/tmp_clas'),
#  PosixPath('/root/.fastai/data/imdb/tmp_lm'),
#  PosixPath('/root/.fastai/data/imdb/train'),
#  PosixPath('/root/.fastai/data/imdb/README'),
#  PosixPath('/root/.fastai/data/imdb/unsup'),
#  PosixPath('/root/.fastai/data/imdb/imdb.vocab'),
#  PosixPath('/root/.fastai/data/imdb/test')]

# %%
(path/'train').ls()
# Out:
# [PosixPath('/root/.fastai/data/imdb/train/labeledBow.feat'),
#  PosixPath('/root/.fastai/data/imdb/train/unsupBow.feat'),
#  PosixPath('/root/.fastai/data/imdb/train/pos'),
#  PosixPath('/root/.fastai/data/imdb/train/neg')]

# %% [markdown]
# The reviews are in a training and test set following an imagenet structure. The only difference is that there is an `unsup` folder on top of `train` and `test` that contains the unlabelled data.
#
# We're not going to train a model that classifies the reviews from scratch. Like in computer vision, we'll use a model pretrained on a bigger dataset (a cleaned subset of wikipedia called [wikitext-103](https://einstein.ai/research/blog/the-wikitext-long-term-dependency-language-modeling-dataset)). That model has been trained to guess what the next word is, its input being all the previous words. It has a recurrent structure and a hidden state that is updated each time it sees a new word. This hidden state thus contains information about the sentence up to that point.
#
# We are going to use that 'knowledge' of the English language to build our classifier, but first, like for computer vision, we need to fine-tune the pretrained model to our particular dataset. Because the English of the reviews left by people on IMDB isn't the same as the English of wikipedia, we'll need to adjust the parameters of our model by a little bit. Plus there might be some words that would be extremely common in the reviews dataset but would be barely present in wikipedia, and therefore might not be part of the vocabulary the model was trained on.

# %% [markdown]
# This is where the unlabelled data is going to be useful to us, as we can use it to fine-tune our model. Let's create our data object with the data block API (next line takes a few minutes).

# %%
data_lm = (TextList.from_folder(path)
           #Inputs: all the text files in path
            .filter_by_folder(include=['train', 'test', 'unsup']) 
           #We may have other temp folders that contain text files so we only keep what's in train and test
            .split_by_rand_pct(0.1)
           #We randomly split and keep 10% (10,000 reviews) for validation
            .label_for_lm()           
           #We want to do a language model so we label accordingly
            .databunch(bs=bs))
data_lm.save('data_lm.pkl')

# %% [markdown]
# We have to use a special kind of `TextDataBunch` for the language model, that ignores the labels (that's why we put 0 everywhere), will shuffle the texts at each epoch before concatenating them all together (only for training, we don't shuffle for the validation set) and will send batches that read that text in order with targets that are the next word in the sentence.
#
# The line before being a bit long, we want to load quickly the final ids by using the following cell.

# %%
data_lm = load_data(path, 'data_lm.pkl', bs=bs)

# %%
data_lm.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>populated with suspicious characters , all connected to a dog show and all having very good reason to murder the apparent suicide victim xxmaj archer xxmaj coe , it 's truly tough to figure this one out or wrap one 's head around it but boy , does it proves fascinating to watch unfold before us . xxmaj even the cops , the coroner and the district attorney prove colorful</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>a max rating , a bit surprised at the mediocre and low ratings by some ; i have tried to address some of the concerns made by two of the reviews with the lowest vote . xxmaj approach this movie as an adventure , and as a xxmaj european movie , not opposed to xxmaj hollywood , but different . xxbos xxmaj no awards show can please all the people</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>lip - reading talent comes into full play using a pair of binoculars . xxmaj there is a teasing , on - again , off - again sexual attraction between the two protagonists that culminates in a rather strange homage to xxup north xxup by xxup northwest , but it works because of the considerable sexual heat that builds slowly between the two stars . xxmaj that being said ,</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>i would not have signed up for a film on child trafficking . \n \n  xxmaj for anyone who would like to watch a powerful film that actually means something i would suggest saving the money on the cinema ticket for the release of ' xxmaj holly ' . xxbos i watched this movie when i was almost quite a kid , and , naturally , was moved to</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>is , i still found it to be a pretty good movie , which is no small feat considering the coma i was put in by the opening scenes . xxmaj to put it mildly , this film has a dreary beginning that was n't even remotely funny , or even upbeat . xxmaj once things get sillier , however , you are left with a comedy that still holds</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can then put this in a learner object very easily with a model loaded with the pretrained weights. They'll be downloaded the first time you'll execute the following line and stored in `~/.fastai/models/` (or elsewhere if you specified different paths in your config file).

# %%
learn = language_model_learner(data_lm, AWD_LSTM, drop_mult=0.3)

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot(skip_end=15)

# %%
learn.fit_one_cycle(1, 1e-2, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.155503</td>
#       <td>4.023906</td>
#       <td>0.295657</td>
#       <td>1:23:41</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('fit_head')

# %%
learn.load('fit_head');

# %% [markdown]
# To complete the fine-tuning, we can then unfeeze and launch a new training.

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(6, 1e-3, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.837844</td>
#       <td>3.812876</td>
#       <td>0.319227</td>
#       <td>1:33:47</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.818506</td>
#       <td>3.766356</td>
#       <td>0.326970</td>
#       <td>1:33:57</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.728629</td>
#       <td>3.709178</td>
#       <td>0.333827</td>
#       <td>1:33:57</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.639567</td>
#       <td>3.660816</td>
#       <td>0.339589</td>
#       <td>1:34:58</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.553269</td>
#       <td>3.634192</td>
#       <td>0.343031</td>
#       <td>1:35:25</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.458821</td>
#       <td>3.631732</td>
#       <td>0.343474</td>
#       <td>1:35:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('fine_tuned')

# %% [markdown]
# How good is our model? Well let's try to see what it predicts after a few given words.

# %%
learn.load('fine_tuned');

# %%
TEXT = "I liked this movie because"
N_WORDS = 40
N_SENTENCES = 2

# %%
print("\n".join(learn.predict(TEXT, N_WORDS, temperature=0.75) for _ in range(N_SENTENCES)))
# Out:
# I liked this movie because it has a very good cast of actors , great actors , and a lot of good writing . The same goes for the special effects . The story line is very well written and well acted .
# I liked this movie because it was Christian . i had the chance to see it one day , and i liked Deadly Brooks , because i know that the director of this movie would have to have a small part in

# %% [markdown]
# We have to save not only the model, but also its encoder, the part that's responsible for creating and updating the hidden state. For the next part, we don't care about the part that tries to guess the next word.

# %%
learn.save_encoder('fine_tuned_enc')

# %% [markdown]
# ## Classifier

# %% [markdown]
# Now, we'll create a new data object that only grabs the labelled data and keeps those labels. Again, this line takes a bit of time.

# %%
path = untar_data(URLs.IMDB)

# %%
data_clas = (TextList.from_folder(path, vocab=data_lm.vocab)
             #grab all the text files in path
             .split_by_folder(valid='test')
             #split by train and valid folder (that only keeps 'train' and 'test' so no need to filter)
             .label_from_folder(classes=['neg', 'pos'])
             #label them all with their folders
             .databunch(bs=bs))

data_clas.save('data_clas.pkl')

# %%
data_clas = load_data(path, 'data_clas.pkl', bs=bs)

# %%
data_clas.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxmaj match 1 : xxmaj tag xxmaj team xxmaj table xxmaj match xxmaj bubba xxmaj ray and xxmaj spike xxmaj dudley vs xxmaj eddie xxmaj guerrero and xxmaj chris xxmaj benoit xxmaj bubba xxmaj ray and xxmaj spike xxmaj dudley started things off with a xxmaj tag xxmaj team xxmaj table xxmaj match against xxmaj eddie xxmaj guerrero and xxmaj chris xxmaj benoit . xxmaj according to the rules</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj by now you 've probably heard a bit about the new xxmaj disney dub of xxmaj miyazaki 's classic film , xxmaj laputa : xxmaj castle xxmaj in xxmaj the xxmaj sky . xxmaj during late summer of 1998 , xxmaj disney released " xxmaj kiki 's xxmaj delivery xxmaj service " on video which included a preview of the xxmaj laputa dub saying it was due out</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj warning : xxmaj does contain spoilers . \n \n  xxmaj open xxmaj your xxmaj eyes \n \n  xxmaj if you have not seen this film and plan on doing so , just stop reading here and take my word for it . xxmaj you have to see this film . i have seen it four times so far and i still have n't made up my</td>
#       <td>pos</td>
#     </tr>
#     <tr>
#       <td>xxbos * * * xxmaj warning - this review contains " plot spoilers , " though nothing could " spoil " this movie any more than it already is . xxmaj it really xxup is that bad . * * * \n \n  xxmaj before i begin , i 'd like to let everyone know that this definitely is one of those so - incredibly - bad - that</td>
#       <td>neg</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup anchors xxup aweigh sees two eager young sailors , xxmaj joe xxmaj brady ( xxmaj gene xxmaj kelly ) and xxmaj clarence xxmaj doolittle / xxmaj brooklyn ( xxmaj frank xxmaj sinatra ) , get a special four - day shore leave . xxmaj eager to get to the girls , particularly xxmaj joe 's xxmaj lola , neither xxmaj joe nor xxmaj brooklyn figure on the interruption</td>
#       <td>pos</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can then create a model to classify those reviews and load the encoder we saved before.

# %%
learn = text_classifier_learner(data_clas, AWD_LSTM, drop_mult=0.5)
learn.load_encoder('fine_tuned_enc')
# Out:
# RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (25000 items)
# x: TextList
# xxbos xxmaj talented detective xxmaj mr. xxmaj philo xxmaj vance ( xxmaj william xxmaj powell ) cancels his overseas trip to investigate an apparently cut and dried case of suicide he has good reason to suspect is really something much more , a rather deliciously complex murder !
#
#   xxmaj as far as murder mystery films go , it just does n't get any better than this one . xxmaj populated with suspicious characters , all connected to a dog show and all having very good reason to murder the apparent suicide victim xxmaj archer xxmaj coe , it 's truly tough to figure this one out or wrap one 's head around it but boy , does it proves fascinating to watch unfold before us . xxmaj even the cops , the coroner and the district attorney prove colorful , fleshed out characters adding a level of unexpected gritty realism to this one 's proceedings and amping up its overall " fun " factor . i particularly enjoyed the comic scenes involving the coroner ( played by xxmaj etienne xxmaj girardot ) , who is always it seems to him being rudely and untimely interrupted by the discovery of corpses or injured men during this one 's running time . xxmaj also xxmaj eugene xxmaj palette 's xxmaj detective xxmaj sgt . xxmaj heath provides welcome , often later delightfully humorous at his expense , critical commentary during xxmaj vance 's investigation . i can not think of any valid criticism to give this movie in fact except perhaps that it has n't dated particularly well . xxmaj does n't stop the movie from being just plain good fun viewing though . xxmaj watch and see if you can wrap your head around this one 's mystery . xxmaj highly recommended you try !,xxbos xxmaj rock ' n ' xxmaj roll xxmaj high xxmaj school was one of the best movies ever made ! i think the only reason it was so awesome was because of xxmaj the xxmaj ramones ! xxmaj you could n't have made the same movie and put something like the xxmaj sex xxmaj pistols , or xxmaj the xxmaj clash in place of xxmaj the xxmaj ramones , it just would n't have been the same . dey young , clint howard , xxmaj vincent xxmaj van xxmaj patten , xxmaj mary xxmaj woronov , xxmaj paul xxmaj bartel , and the hall xxunk , just added to the movie . xxmaj the whole entire movie is about xxmaj the xxmaj ramones ... especially xxmaj joey ! xxmaj so everybody showed see xxmaj rock ' n ' xxmaj roll xxmaj high xxmaj school if your a huge fan of real xxup punk . xxmaj not the sissy new crap ... but the loud , and fast kind . xxmaj the kind only xxmaj the xxmaj ramones could do . xxup r.i.p ( xxmaj rest xxmaj in xxmaj peace ) xxmaj joey xxmaj ramone 1951 - 2001 . xxmaj dee xxmaj dee xxmaj ramone 1952 - 2002 !,xxbos xxmaj karloff and xxmaj lugosi - xxmaj together again ! xxmaj this is one of those films that casual fans will pass over and tend not to appreciate as much . xxmaj it 's not an all - out horror film like the duo 's previous two hits , xxmaj the xxmaj black xxmaj cat and xxmaj the xxmaj raven . xxmaj but , it is very worthy of both 's talents and is a fun film when re - visited .
#
#   xxmaj the xxmaj invisible xxmaj ray was directed by xxmaj lambert xxmaj hillyer , a director who mainly made westerns , but curiously in these final days of the xxmaj xxunk ' reign at xxmaj universal , he found himself helming this and the xxmaj xxunk ' final horror film , xxmaj dracula 's xxmaj daughter . xxmaj both are crisp , clean - cut fantasies that are very light on horror content despite the fantastic elements .
#
#   xxmaj just as xxmaj lugosi went wild in xxmaj the xxmaj raven , much needs to be said of xxmaj karloff 's hamming in xxmaj the xxmaj invisible xxmaj ray . xxmaj the one aspect of the story that is particularly unsatisfying is that xxmaj karloff 's character , xxmaj rukh , acts so madly before he is poisoned by xxmaj radium x , that there really is n't much of a change once he starts glowing . xxmaj this is very similar to the complaint people have about xxmaj jack xxmaj nicholson in xxmaj the xxmaj shining - xxmaj he 's basically a loony right from the start . xxmaj there is n't any real transformation . xxmaj same here . xxmaj halfway through xxmaj karloff simply has an added purpose for revenge in his mind . i still enjoyed his performance , though , just as i did xxmaj lugosi 's over - the - top antics in xxmaj the xxmaj raven .
#
#   xxmaj meanwhile , xxmaj lugosi completely surprises you and gives a restrained , and thoughtful turn as xxmaj rukh 's rival in science , xxmaj dr. xxmaj benet . xxmaj lugosi also has some of the best lines in the film , including a memorable warning to the police trying to catch xxmaj rukh , of which i am in alignment with horror film writer xxmaj john xxmaj xxunk on - " xxmaj and if he ( xxmaj rukh ) touches anyone ? " the inspector inquires . xxmaj lugosi xxunk replies , in a way that only xxmaj lugosi could deliver , " xxmaj they die " . xxmaj just as xxmaj lugosi could be so off , he could also be more perfect than any actor . xxmaj this is one of those moments .
#
#   xxmaj therefore , xxmaj karloff and xxmaj lugosi 's interactions are all very good as we get the mad antics of xxmaj karloff pared off against the cool logic of xxmaj lugosi . xxmaj karloff would go on to play similar mad scientists many times , however , one wishes xxmaj lugosi would have gotten to play more straight roles like this one . xxmaj he only had one more chance ( xxmaj ninotchka ) .
#
#   xxmaj the xxmaj invisible xxmaj ray is a fun film , and a real treat to the true xxmaj karloff and xxmaj lugosi fans . xxmaj it is one of those films that improves on each viewing , not because it is a masterpiece , but because of the charisma and talent of its ' stars and how this story complements the darker , more horrific pairings they had . xxmaj the special effects , by the always innovative xxmaj john xxmaj fulton , are terrific and the supporting actors are all adequate . xxmaj frances xxmaj drake looks as beautiful as she did in xxmaj mad xxmaj love and plays a strong woman , something seldom seen in classic horror films . xxmaj the scene in the end when xxmaj karloff stalks her and she does n't scream is one of the most haunting moments of the film . a terrific , fun film !,xxbos xxmaj leave it to xxmaj xxunk to put on a good show . xxmaj finally he and xxmaj zorak are living their own lives outside of xxmaj xxunk xxmaj ghost xxmaj coast xxmaj to xxmaj coast . i have to say that i love both of these shows a whole lot . xxmaj they are completely what started xxmaj adult xxmaj swim . xxmaj brak made it big with an album that came out in the year 2000 . xxmaj it may not have been platinum , but his show was really popular to tons of people out there that love xxmaj adult xxmaj swims shows . i have to say that out of all the xxmaj adult xxmaj swim shows with no plot , this has to be the one with the most none plot ever made . xxmaj that is why i like it so much , it is just such a classic in the xxmaj adult xxmaj swim history . i believe this is just such a great show , if you do n't like it . xxmaj hey there were tons who hated it and tons who loved it .,xxbos this is the best sci - fi that i have seen in my 29 years of watching sci - fi . i also believe that xxmaj dark xxmaj angel will become a cult favorite . xxmaj the action is great but xxmaj jessica xxmaj alba is the best and most gorgeous star on xxup tv today .
# y: CategoryList
# pos,pos,pos,pos,pos
# Path: /content/data/imdb;
#
# Valid: LabelList (25000 items)
# x: TextList
# xxbos xxmaj it worked ! xxmaj director xxmaj christian xxmaj duguay created a very clever action / spy thriller . xxmaj the actors xxmaj donald xxmaj sutherland and especially xxmaj aidan xxmaj quinn gave a top performance . xxmaj what a pity that we couldn´t see xxmaj aidan xxmaj quinn in others movies like this one till now . xxmaj he was simply the best in the role as xxmaj ramirez / xxmaj carlos for what he should have earned the xxmaj oscar . xxmaj the picture was very nice . xxmaj the scenes are fast paced from beginning to the end and the story doesn´t let you a chance to get bored . xxmaj the movie is too underrated and i recommend it to anyone otherwise you will miss something great . xxmaj believe me you will not be disappointed . xxmaj that´s why i give it 9 / 10 .,xxbos i 'm not a big xxup tv person ... but when i saw the premier episode of xxmaj greek , i could n't wait until next week ! i do n't miss the show for xxup nothing !
#
#   xxup thank xxup god for xxup dvr ! xxup lol i 'm in love with xxmaj cappie ... he acts like a bad boy , but he is so sweet ... xxmaj everybody has their own character so , we have pretty much all types of people . xxmaj you could still throw in a xxmaj hispanic and a chubby persons .
#
#   i did n't go to school in xxup usa , so , i never liked the idea of frat houses and stuff like that , so , when my husband told me about the show i did n't pay attention , until he asked me to watch it and since i did n't have noting better to do , i agreed . i laughed xxup so hard the first night that i just needed to keep watching it .
#
#   xxmaj so .. i 'm with the other people that voted for this show to continue on ! i will hope for a second , third and who knows how many more episodes ! xxmaj its a really good show , very funny and entertaining !,xxbos xxmaj jennifer xxmaj montgomery 's " xxmaj art for xxmaj teachers of xxmaj children " is a stunning , disturbing masterpiece . xxmaj montgomery 's gritty camerawork and cinematography coupled with the brilliantly unemotional performances she evokes from her cast heighten the sense of shocking , raw realism in this autobiographical story of a 14-year - old xxmaj jennifer 's seduction of her married boarding - school guidance counselor . xxmaj the scenes between the amazingly uncanny actress playing xxmaj jennifer ( xxmaj caitlin xxmaj grace mcdonnell ) and xxmaj jennifer 's mother ( actually voiced by xxmaj ruth xxmaj montgomery ) on the phone are some of the most intriguing and powerful i 've ever seen captured on film . xxmaj the lesson ultimately learned here ? " xxmaj there 's nothing more dangerous than a boring man who creates bad art . " xxmaj well , i would highly recommend this remarkable piece of " xxmaj art " for anyone interested in thought - provoking independent cinema .,xxbos xxmaj perhaps one of the first slasher film that came out after xxmaj halloween ( xxmaj although made from xxmaj irwin xxmaj xxunk from xxmaj halloween ) , i must say i honestly found " xxmaj tourist xxmaj trap " to be scarier and funner . " xxmaj tourist xxmaj trap " is one of those remarkable treats you find every now and then , and are left with the most enjoyable feeling of surprise . xxmaj it was destiny i tell you , but one night i was at my local xxmaj blockbuster ( xxmaj one or xxmaj two months before it went out of business ) , and had nothing to get . xxmaj then i stumble upon this movie , i think huh seems like a laughable b - xxmaj movie , i rent it and took it home , boy was i in for a good scare . " xxmaj tourist xxmaj trap " comes off as a bad movie , it definitely has it 's cheesy moments , but in the end you 're having to much fun with it to really care .
#
#   xxmaj the things that impressed me the absolute most , and the things that made this movie one of the scariest ones i 've seen , is number one the setting . a horror movie without a good setting is n't very fun , not here . i just love love love the location , it feels like we can relate to it , it almost feels like we 've been there before . xxmaj which makes it creepier . xxmaj next is the characters , non of them are really stereotypical , and they all have a real personality . xxmaj for example they 're not stoners , alcoholics , or even xxmaj sex obsessed people , they feel like normal young adults . xxmaj plus they look realistic enough , and then their is xxmaj chuck xxmaj connors . xxmaj who gives a great performance as xxmaj mr. xxmaj slausen who we all take an instant liking too because again he 's so real , he feels like that nice guy grandfatherly figure we adore . xxmaj the last , and probably most important thing that makes this movie scary is how they make us ( the audience ) jump half way out of our seats , and turn on the rights , for the right reasons . xxmaj for example most of the time in horror films we mainly just jump because of a sudden change in the music pitch , but in " xxmaj tourist xxmaj trap " prepare yourself , that 's not the case . xxmaj with it 's perfect use of lighting , mannequins , and weirdness you feel utterly creeped out . xxmaj plus i love because although they may go a bit over - the - top with some things you still feel like this could happen . xxmaj which is exactly what a horror movie who takes such a ridicules premise should do , and that is make us ( the audience ) feel unsafe and terrified .
#
#   xxmaj overall as far as any major problems go , i have none , only that it 's weirdness may get a little too weird at times . xxmaj however in the end " xxmaj tourist xxmaj trap " holds a place near and dear to my heart , for being one of the few horror films to make me turn on the lights and feel unsafe about traveling .,xxbos xxmaj ca n't say this was n't made well . xxmaj at a recent film festival the director admitted some scenes took 30 takes . xxmaj and there is n't the slightest indication he did n't get exactly what he wanted . xxmaj but this is an oddly non - xxmaj hispanic film in the same way xxmaj west xxmaj side xxmaj story was many years ago . xxmaj both the leads , a brother - sister team , are excellent and memorable in their parts . xxmaj the setting , a sort of underground car repair district in xxmaj queens , is completely foreign to most people and is worth the price of admission by itself . xxmaj but there 's something unsatisfying about the key issue in the film , namely , what the sister feels she has to do to get by . i can understand the brother 's reaction , but it just seems a little too easily come by to me . xxmaj the movie seems to suggest that people like these do n't need our help , that they 'll find a way to survive without the usual support systems . i would n't encourage anyone to believe that . xxmaj there would be far more resistance to the choices made here than depicted . xxmaj other than that as an entertainment it works well . xxmaj as an accurate depiction of a culture , not so well , i think .
# y: CategoryList
# pos,pos,pos,pos,pos
# Path: /content/data/imdb;
#
# Test: None, model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(60000, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(60000, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7f022d64ef28>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('/content/data/imdb'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[RNNTrainer
# learn: RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (25000 items)
# x: TextList
# xxbos xxmaj talented detective xxmaj mr. xxmaj philo xxmaj vance ( xxmaj william xxmaj powell ) cancels his overseas trip to investigate an apparently cut and dried case of suicide he has good reason to suspect is really something much more , a rather deliciously complex murder !
#
#   xxmaj as far as murder mystery films go , it just does n't get any better than this one . xxmaj populated with suspicious characters , all connected to a dog show and all having very good reason to murder the apparent suicide victim xxmaj archer xxmaj coe , it 's truly tough to figure this one out or wrap one 's head around it but boy , does it proves fascinating to watch unfold before us . xxmaj even the cops , the coroner and the district attorney prove colorful , fleshed out characters adding a level of unexpected gritty realism to this one 's proceedings and amping up its overall " fun " factor . i particularly enjoyed the comic scenes involving the coroner ( played by xxmaj etienne xxmaj girardot ) , who is always it seems to him being rudely and untimely interrupted by the discovery of corpses or injured men during this one 's running time . xxmaj also xxmaj eugene xxmaj palette 's xxmaj detective xxmaj sgt . xxmaj heath provides welcome , often later delightfully humorous at his expense , critical commentary during xxmaj vance 's investigation . i can not think of any valid criticism to give this movie in fact except perhaps that it has n't dated particularly well . xxmaj does n't stop the movie from being just plain good fun viewing though . xxmaj watch and see if you can wrap your head around this one 's mystery . xxmaj highly recommended you try !,xxbos xxmaj rock ' n ' xxmaj roll xxmaj high xxmaj school was one of the best movies ever made ! i think the only reason it was so awesome was because of xxmaj the xxmaj ramones ! xxmaj you could n't have made the same movie and put something like the xxmaj sex xxmaj pistols , or xxmaj the xxmaj clash in place of xxmaj the xxmaj ramones , it just would n't have been the same . dey young , clint howard , xxmaj vincent xxmaj van xxmaj patten , xxmaj mary xxmaj woronov , xxmaj paul xxmaj bartel , and the hall xxunk , just added to the movie . xxmaj the whole entire movie is about xxmaj the xxmaj ramones ... especially xxmaj joey ! xxmaj so everybody showed see xxmaj rock ' n ' xxmaj roll xxmaj high xxmaj school if your a huge fan of real xxup punk . xxmaj not the sissy new crap ... but the loud , and fast kind . xxmaj the kind only xxmaj the xxmaj ramones could do . xxup r.i.p ( xxmaj rest xxmaj in xxmaj peace ) xxmaj joey xxmaj ramone 1951 - 2001 . xxmaj dee xxmaj dee xxmaj ramone 1952 - 2002 !,xxbos xxmaj karloff and xxmaj lugosi - xxmaj together again ! xxmaj this is one of those films that casual fans will pass over and tend not to appreciate as much . xxmaj it 's not an all - out horror film like the duo 's previous two hits , xxmaj the xxmaj black xxmaj cat and xxmaj the xxmaj raven . xxmaj but , it is very worthy of both 's talents and is a fun film when re - visited .
#
#   xxmaj the xxmaj invisible xxmaj ray was directed by xxmaj lambert xxmaj hillyer , a director who mainly made westerns , but curiously in these final days of the xxmaj xxunk ' reign at xxmaj universal , he found himself helming this and the xxmaj xxunk ' final horror film , xxmaj dracula 's xxmaj daughter . xxmaj both are crisp , clean - cut fantasies that are very light on horror content despite the fantastic elements .
#
#   xxmaj just as xxmaj lugosi went wild in xxmaj the xxmaj raven , much needs to be said of xxmaj karloff 's hamming in xxmaj the xxmaj invisible xxmaj ray . xxmaj the one aspect of the story that is particularly unsatisfying is that xxmaj karloff 's character , xxmaj rukh , acts so madly before he is poisoned by xxmaj radium x , that there really is n't much of a change once he starts glowing . xxmaj this is very similar to the complaint people have about xxmaj jack xxmaj nicholson in xxmaj the xxmaj shining - xxmaj he 's basically a loony right from the start . xxmaj there is n't any real transformation . xxmaj same here . xxmaj halfway through xxmaj karloff simply has an added purpose for revenge in his mind . i still enjoyed his performance , though , just as i did xxmaj lugosi 's over - the - top antics in xxmaj the xxmaj raven .
#
#   xxmaj meanwhile , xxmaj lugosi completely surprises you and gives a restrained , and thoughtful turn as xxmaj rukh 's rival in science , xxmaj dr. xxmaj benet . xxmaj lugosi also has some of the best lines in the film , including a memorable warning to the police trying to catch xxmaj rukh , of which i am in alignment with horror film writer xxmaj john xxmaj xxunk on - " xxmaj and if he ( xxmaj rukh ) touches anyone ? " the inspector inquires . xxmaj lugosi xxunk replies , in a way that only xxmaj lugosi could deliver , " xxmaj they die " . xxmaj just as xxmaj lugosi could be so off , he could also be more perfect than any actor . xxmaj this is one of those moments .
#
#   xxmaj therefore , xxmaj karloff and xxmaj lugosi 's interactions are all very good as we get the mad antics of xxmaj karloff pared off against the cool logic of xxmaj lugosi . xxmaj karloff would go on to play similar mad scientists many times , however , one wishes xxmaj lugosi would have gotten to play more straight roles like this one . xxmaj he only had one more chance ( xxmaj ninotchka ) .
#
#   xxmaj the xxmaj invisible xxmaj ray is a fun film , and a real treat to the true xxmaj karloff and xxmaj lugosi fans . xxmaj it is one of those films that improves on each viewing , not because it is a masterpiece , but because of the charisma and talent of its ' stars and how this story complements the darker , more horrific pairings they had . xxmaj the special effects , by the always innovative xxmaj john xxmaj fulton , are terrific and the supporting actors are all adequate . xxmaj frances xxmaj drake looks as beautiful as she did in xxmaj mad xxmaj love and plays a strong woman , something seldom seen in classic horror films . xxmaj the scene in the end when xxmaj karloff stalks her and she does n't scream is one of the most haunting moments of the film . a terrific , fun film !,xxbos xxmaj leave it to xxmaj xxunk to put on a good show . xxmaj finally he and xxmaj zorak are living their own lives outside of xxmaj xxunk xxmaj ghost xxmaj coast xxmaj to xxmaj coast . i have to say that i love both of these shows a whole lot . xxmaj they are completely what started xxmaj adult xxmaj swim . xxmaj brak made it big with an album that came out in the year 2000 . xxmaj it may not have been platinum , but his show was really popular to tons of people out there that love xxmaj adult xxmaj swims shows . i have to say that out of all the xxmaj adult xxmaj swim shows with no plot , this has to be the one with the most none plot ever made . xxmaj that is why i like it so much , it is just such a classic in the xxmaj adult xxmaj swim history . i believe this is just such a great show , if you do n't like it . xxmaj hey there were tons who hated it and tons who loved it .,xxbos this is the best sci - fi that i have seen in my 29 years of watching sci - fi . i also believe that xxmaj dark xxmaj angel will become a cult favorite . xxmaj the action is great but xxmaj jessica xxmaj alba is the best and most gorgeous star on xxup tv today .
# y: CategoryList
# pos,pos,pos,pos,pos
# Path: /content/data/imdb;
#
# Valid: LabelList (25000 items)
# x: TextList
# xxbos xxmaj it worked ! xxmaj director xxmaj christian xxmaj duguay created a very clever action / spy thriller . xxmaj the actors xxmaj donald xxmaj sutherland and especially xxmaj aidan xxmaj quinn gave a top performance . xxmaj what a pity that we couldn´t see xxmaj aidan xxmaj quinn in others movies like this one till now . xxmaj he was simply the best in the role as xxmaj ramirez / xxmaj carlos for what he should have earned the xxmaj oscar . xxmaj the picture was very nice . xxmaj the scenes are fast paced from beginning to the end and the story doesn´t let you a chance to get bored . xxmaj the movie is too underrated and i recommend it to anyone otherwise you will miss something great . xxmaj believe me you will not be disappointed . xxmaj that´s why i give it 9 / 10 .,xxbos i 'm not a big xxup tv person ... but when i saw the premier episode of xxmaj greek , i could n't wait until next week ! i do n't miss the show for xxup nothing !
#
#   xxup thank xxup god for xxup dvr ! xxup lol i 'm in love with xxmaj cappie ... he acts like a bad boy , but he is so sweet ... xxmaj everybody has their own character so , we have pretty much all types of people . xxmaj you could still throw in a xxmaj hispanic and a chubby persons .
#
#   i did n't go to school in xxup usa , so , i never liked the idea of frat houses and stuff like that , so , when my husband told me about the show i did n't pay attention , until he asked me to watch it and since i did n't have noting better to do , i agreed . i laughed xxup so hard the first night that i just needed to keep watching it .
#
#   xxmaj so .. i 'm with the other people that voted for this show to continue on ! i will hope for a second , third and who knows how many more episodes ! xxmaj its a really good show , very funny and entertaining !,xxbos xxmaj jennifer xxmaj montgomery 's " xxmaj art for xxmaj teachers of xxmaj children " is a stunning , disturbing masterpiece . xxmaj montgomery 's gritty camerawork and cinematography coupled with the brilliantly unemotional performances she evokes from her cast heighten the sense of shocking , raw realism in this autobiographical story of a 14-year - old xxmaj jennifer 's seduction of her married boarding - school guidance counselor . xxmaj the scenes between the amazingly uncanny actress playing xxmaj jennifer ( xxmaj caitlin xxmaj grace mcdonnell ) and xxmaj jennifer 's mother ( actually voiced by xxmaj ruth xxmaj montgomery ) on the phone are some of the most intriguing and powerful i 've ever seen captured on film . xxmaj the lesson ultimately learned here ? " xxmaj there 's nothing more dangerous than a boring man who creates bad art . " xxmaj well , i would highly recommend this remarkable piece of " xxmaj art " for anyone interested in thought - provoking independent cinema .,xxbos xxmaj perhaps one of the first slasher film that came out after xxmaj halloween ( xxmaj although made from xxmaj irwin xxmaj xxunk from xxmaj halloween ) , i must say i honestly found " xxmaj tourist xxmaj trap " to be scarier and funner . " xxmaj tourist xxmaj trap " is one of those remarkable treats you find every now and then , and are left with the most enjoyable feeling of surprise . xxmaj it was destiny i tell you , but one night i was at my local xxmaj blockbuster ( xxmaj one or xxmaj two months before it went out of business ) , and had nothing to get . xxmaj then i stumble upon this movie , i think huh seems like a laughable b - xxmaj movie , i rent it and took it home , boy was i in for a good scare . " xxmaj tourist xxmaj trap " comes off as a bad movie , it definitely has it 's cheesy moments , but in the end you 're having to much fun with it to really care .
#
#   xxmaj the things that impressed me the absolute most , and the things that made this movie one of the scariest ones i 've seen , is number one the setting . a horror movie without a good setting is n't very fun , not here . i just love love love the location , it feels like we can relate to it , it almost feels like we 've been there before . xxmaj which makes it creepier . xxmaj next is the characters , non of them are really stereotypical , and they all have a real personality . xxmaj for example they 're not stoners , alcoholics , or even xxmaj sex obsessed people , they feel like normal young adults . xxmaj plus they look realistic enough , and then their is xxmaj chuck xxmaj connors . xxmaj who gives a great performance as xxmaj mr. xxmaj slausen who we all take an instant liking too because again he 's so real , he feels like that nice guy grandfatherly figure we adore . xxmaj the last , and probably most important thing that makes this movie scary is how they make us ( the audience ) jump half way out of our seats , and turn on the rights , for the right reasons . xxmaj for example most of the time in horror films we mainly just jump because of a sudden change in the music pitch , but in " xxmaj tourist xxmaj trap " prepare yourself , that 's not the case . xxmaj with it 's perfect use of lighting , mannequins , and weirdness you feel utterly creeped out . xxmaj plus i love because although they may go a bit over - the - top with some things you still feel like this could happen . xxmaj which is exactly what a horror movie who takes such a ridicules premise should do , and that is make us ( the audience ) feel unsafe and terrified .
#
#   xxmaj overall as far as any major problems go , i have none , only that it 's weirdness may get a little too weird at times . xxmaj however in the end " xxmaj tourist xxmaj trap " holds a place near and dear to my heart , for being one of the few horror films to make me turn on the lights and feel unsafe about traveling .,xxbos xxmaj ca n't say this was n't made well . xxmaj at a recent film festival the director admitted some scenes took 30 takes . xxmaj and there is n't the slightest indication he did n't get exactly what he wanted . xxmaj but this is an oddly non - xxmaj hispanic film in the same way xxmaj west xxmaj side xxmaj story was many years ago . xxmaj both the leads , a brother - sister team , are excellent and memorable in their parts . xxmaj the setting , a sort of underground car repair district in xxmaj queens , is completely foreign to most people and is worth the price of admission by itself . xxmaj but there 's something unsatisfying about the key issue in the film , namely , what the sister feels she has to do to get by . i can understand the brother 's reaction , but it just seems a little too easily come by to me . xxmaj the movie seems to suggest that people like these do n't need our help , that they 'll find a way to survive without the usual support systems . i would n't encourage anyone to believe that . xxmaj there would be far more resistance to the choices made here than depicted . xxmaj other than that as an entertainment it works well . xxmaj as an accurate depiction of a culture , not so well , i think .
# y: CategoryList
# pos,pos,pos,pos,pos
# Path: /content/data/imdb;
#
# Test: None, model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(60000, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(60000, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7f022d64ef28>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('/content/data/imdb'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[...], layer_groups=[Sequential(
#   (0): Embedding(60000, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(60000, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# )], add_time=True, silent=False)
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): Embedding(60000, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(60000, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# )], add_time=True, silent=False)

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(1, 2e-2, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.264784</td>
#       <td>0.185984</td>
#       <td>0.927080</td>
#       <td>09:37</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('first')

# %%
learn.load('first');

# %%
learn.freeze_to(-2)
learn.fit_one_cycle(1, slice(1e-2/(2.6**4),1e-2), moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.245840</td>
#       <td>0.163696</td>
#       <td>0.938520</td>
#       <td>10:34</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('second')

# %%
learn.load('second');

# %%
learn.freeze_to(-3)
learn.fit_one_cycle(1, slice(5e-3/(2.6**4),5e-3), moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.180483</td>
#       <td>0.144677</td>
#       <td>0.946200</td>
#       <td>15:57</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('third')

# %%
learn.load('third');

# %%
learn.predict("I really loved that movie, it was awesome!")
# Out:
# (Category pos, tensor(1), tensor([5.1734e-05, 9.9995e-01]))

# %%
learn.predict("I hated this movie!")
# Out:
# (Category neg, tensor(0), tensor([0.9982, 0.0018]))

# %%
learn.predict("I absolutely loved this movie!")
# Out:
# (Category pos, tensor(1), tensor([9.2648e-05, 9.9991e-01]))

# %%
learn.predict("Movie was not too bad.")
# Out:
# (Category neg, tensor(0), tensor([0.7869, 0.2131]))
